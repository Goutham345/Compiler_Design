# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham345/Compiler_Design/blob/main/Lab-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install -y flex bison gcc
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:13.2.0-7ubuntu1).
# gcc set to manually installed.
# The following additional packages will be installed:
#   libfl-dev libfl2
# Suggested packages:
#   bison-doc flex-doc
# The following NEW packages will be installed:
#   bison flex libfl-dev libfl2
# 0 upgraded, 4 newly installed, 0 to remove and 28 not upgraded.
# Need to get 1,065 kB of archives.
# After this operation, 3,583 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/main amd64 flex amd64 2.6.4-8.2build1 [301 kB]
# Get:2 http://archive.ubuntu.com/ubuntu noble/main amd64 bison amd64 2:3.8.2+dfsg-1build2 [749 kB]
# ...

# %%
# %%writefile example.l
#
# %{
#   #include <stdio.h>
#   int a,b;
# %}
# %%
# ba+ {printf("Positive close");}
# cd* {printf("clear closure");}
# %%
# int main()
# {
#   yylex();
#   return 0;
# }
# yywrap()
# {
#   return 1;
# }
# Out:
# Overwriting example.l

# %%
# !flex example.l

# %%
# !gcc lex.yy.c -o example
# Out:
# example.l:15:1: warning: return type defaults to ‘int’ [-Wimplicit-int]
#    15 | yywrap()
#       | ^~~~~~

# %%
# !./example
# Out:
# ba
# Positive close
# baa
# Positive close
# ca
# clear closurea
# caa
# clear closureaa
# end
# end
# ^C

# %%
# %%writefile example.l
#
# %{
#   #include <stdio.h>
#   int a,b;
# %}
# %%
# ab{2,5} {printf("limit");}
# cd?a* {printf("zero or one");}
# %%
# int main()
# {
#   yylex();
#   return 0;
# }
# yywrap()
# {
#   return 1;
# }
# Out:
# Overwriting example.l

# %%
# !flex example.l

# %%
# !gcc lex.yy.c -o lexprog
# Out:
# example.l:15:1: warning: return type defaults to ‘int’ [-Wimplicit-int]
#    15 | yywrap()
#       | ^~~~~~

# %%
# !./lexprog
# Out:
# cdee
# zero or oneee
# abbb
# limit
# ab
# ab
# ^C
